# %%
# 준비작업
import pandas as pd
foodData = pd.read_excel('/content/drive/MyDrive/혼자하는거/food.xlsx')
foodData

# %%
# 준비작업 2

stores = {
    '스무디': '윤아의 스무디킹',
    '커피': '유빈이의 설빙',
    '식품': '영현이의 맘스터치'
}

stores

# %%
userData = input('뭘 원해?')

if '스무디' in userData :
    recommended_store = foodData['스무디 가게'].values[0]
    print(f'{userData }? {recommended_store}으로 가봐!')

elif userData in food['커피']:
    recommended_store = foodData['커피를 파는 가게'].values[0]
    print(f'{userData}? {recommended_store}로 가봐!')

elif userData in food['씹어먹을 수 있는 것']:
    recommended_store = foodData['씹어먹을 수 있는 것을 파는 가게'].values[0]
    print(f'{userData}? {recommended_store}로 가봐!')



else:
    print('일치하는 항목을 찾을 수 없어요.')
